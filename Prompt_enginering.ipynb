# %% [markdown]
# <a href="https://colab.research.google.com/github/ishupatil/AI-ADVANCED-COHORT/blob/main/Prompt_enginering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
from transformers import pipeline
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.56.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.35.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.8.3)

# %%
# Load a local model (e.g., sentiment-analysis)
sentiment_model = pipeline("sentiment-analysis")
text_generation_model = pipeline("text-generation", model="gpt2")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# Device set to use cpu
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu

# %%
# 🔍 Task 1: Summarization Prompting

paragraph = """The quick brown fox jumps over the lazy dog to reach the other side of the hill."""

# Zero-shot prompt
zero_shot_prompt = f"Summarize the following paragraph:\n{paragraph}"
print("🔹 Zero-shot Summary:")
print(text_generation_model(zero_shot_prompt, max_length=50)[0]['generated_text'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 🔹 Zero-shot Summary:
# Summarize the following paragraph:
# The quick brown fox jumps over the lazy dog to reach the other side of the hill. The lazy dog is quickly caught by the big cat. The lazy dog then jumps down. The lazy dog then jumps up. The lazy dog then jumps down.
# Notice that the lazy dog is not actually jumping up. Instead, the lazy dog is jumping down. The lazy dog is only trying to catch the lazy dog.
# Now, what if it were possible for these two animals to escape a predator by jumping up?
# Notice that the lazy dog simply jumps over the lazy dog instead of jumping down.
# Let's look at the following example.
# Notice that the lazy dog is not jumping up. Instead, the lazy dog jumps down.
# Notice how the lazy dog is trying to catch the lazy dog. Notice that the lazy dog is trying to catch the lazy dog.
# Notice that the lazy dog is jumping over the lazy dog. Notice how the lazy dog is jumping over the lazy dog. Notice how the lazy dog is jumping over the lazy dog.
# Notice that the lazy dog is jumping over the lazy dog. Notice the lazy dog is jumping over the lazy dog. Notice the lazy dog is jumping over the lazy dog.
# Notice that the lazy dog is jumping over the lazy dog. Notice the lazy dog is jumping over the lazy dog.
# Notice that

# %%
# 🔍 Task 1: Summarization Prompting

paragraph = """The quick brown fox jumps over the lazy dog to reach the other side of the hill."""

# Zero-shot prompt
zero_shot_prompt = f"Summarize the following paragraph:\n{paragraph}"
print("🔹 Zero-shot Summary:")
print(text_generation_model(zero_shot_prompt, max_length=50)[0]['generated_text'])

# Few-shot prompt
few_shot_prompt = """Example: 'She went to the store, bought groceries, and came back home in the afternoon.'
Summary: She bought groceries and returned home.

Now summarize the following paragraph:
""" + paragraph
print("\n🔹 Few-shot Summary:")
print(text_generation_model(few_shot_prompt, max_length=50)[0]['generated_text'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 🔹 Zero-shot Summary:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Summarize the following paragraph:
# The quick brown fox jumps over the lazy dog to reach the other side of the hill. The dog has a great jump and runs down the hill.
#
# The quick brown fox jumps over the lazy dog to reach the other side of the hill. The dog has a great jump and runs down the hill. The quick brown fox jumps over the lazy dog to reach the other side of the hill. The dog has a great jump and runs down the hill. The quick brown fox jumps over the lazy dog to reach the other side of the hill.
#
# The quick brown fox jumps over the lazy dog to reach the other side of the hill. The dog has a great jump and runs down the hill. The quick brown fox jumps over the lazy dog to reach the other side of the hill. The dog has a great jump and runs down the hill. The quick brown fox jumps over the lazy dog to reach the other side of the hill. The dog has a great jump and runs down the hill. The quick brown fox jumps over the lazy dog to reach the other side of the hill. The dog has a great jump and runs down the hill. The quick brown fox jumps over the lazy dog to reach the other side of the hill. The dog has a great jump and runs down the hill. The quick brown fox jumps over the lazy dog to reach the
#
# 🔹 Few-shot Summary:
# Example: 'She went to the store, bought groceries, and came back home in the afternoon.'
# Summary: She bought groceries and returned home.
#
# Now summarize the following paragraph:
# The quick brown fox jumps over the lazy dog to reach the other side of the hill. the store. In the end, he has the cash and a nice jacket. He's got a nice big wallet.
#
# The quick brown fox jumps over the lazy dog to reach the store. In the end, he has the cash and a nice jacket. He's got a nice big wallet. The quick brown fox jumps over the lazy dog and gets the dog back to his house, where the dog is sitting.
#
# Summary: The quick brown fox comes back to the store to buy groceries. He's there to pay the rent, and the dog is there to get the dog back to his house. However, the fox isn't there to pay the rent because he's not sure if the dog is still there.
#
# Summary: The quick brown fox jumps over the lazy dog and gets the dog back to his house. However, the fox isn't there to pay the rent because he's not sure if the dog is still there. The quick brown fox jumps over the lazy dog and the dog is there to get the dog back to his house. However, the fox isn't there to pay the rent because he's not sure if the dog is still there.
#
# Summary: The quick brown fox jumps over the lazy dog and gets the dog back

# %%
# 🧪 Task 2: Sentiment Classification

review_text = "The new update is fantastic – it made the app so much smoother and I absolutely love it!"

# Basic prompt
print("\n🔹 Basic Sentiment Classification:")
print(sentiment_model(review_text))

# Role-based prompt (simulated)
role_based_prompt = f"You are a sentiment analysis expert. Classify the sentiment of this review: '{review_text}'"
print("\n🔹 Role-based Sentiment Classification (simulated):")
print(text_generation_model(role_based_prompt, max_length=50)[0]['generated_text'])
# Out:
# 🔹 Basic Sentiment Classification:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'label': 'POSITIVE', 'score': 0.9998791217803955}]
#
# 🔹 Role-based Sentiment Classification (simulated):
# You are a sentiment analysis expert. Classify the sentiment of this review: 'The new update is fantastic – it made the app so much smoother and I absolutely love it!' I also recommend you check out my other reviews: 'Do you know what the new iOS 10 is?'
#
# The app is the best iPhone app I've ever used.
#
# So, I'm going to take you through all the new features, and explain why I think it's the best iPhone app you've ever used.
#
# If you're not a fan, here's the list of things I've written about the new iOS 10 update.
#
# This isn't necessarily a review of the new update. There are many other things that are new.
#
# This is also a list of things that are missing from the update.
#
# Here is a list of things that are missing from the update:
#
# I've updated the App Store to the new version of iOS 10.
#
# The app is now free.
#
# When I say free, I mean the free version.
#
# If you are not a fan of the iOS 10 update as a developer, then you need to keep reading and waiting for a more comprehensive list of updates.
#
# Here's the list of things I've written about the new iOS 10 update.
#
# I've also upgraded my iPhone to iOS 10.
#
# I've updated the App Store to the new

# %%
# 🧠 Task 3: Q&A with Chain-of-Thought

question = "If a bat and a ball cost $1.10 total, and the bat costs $1.00 more than the ball, how much does the ball cost?"

# Direct prompt
direct_prompt = f"Q: {question}\nA:"
print("\n🔹 Direct Answer:")
print(text_generation_model(direct_prompt, max_length=50)[0]['generated_text'])

# Chain-of-thought prompt
cot_prompt = f"Q: {question}\nLet's think step by step."
print("\n🔹 Chain-of-Thought Answer:")
print(text_generation_model(cot_prompt, max_length=150)[0]['generated_text'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 🔹 Direct Answer:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=150) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Q: If a bat and a ball cost $1.10 total, and the bat costs $1.00 more than the ball, how much does the ball cost?
# A: The cost of the bat and ball are the same. The cost of the bat and ball are equal to the cost of the ball. If the bat is $1.10, the difference is $1.00. If the ball is $1.00, the difference is $1.00.
# B: Does one bat cost $1.10 for the ball, $4.50 for the bat?
# A: Yes, one bat costs $1.10 for the ball.
# B: Where does a bat (or ball) cost $1.10?
# A: In a $1.10 ball, the bat is $1.10 with a bat weight of $30.
# B: How much does a bat cost $1.10 for the ball?
# A: The bat is $1.10 with a bat weight of $30.
# B: That is, the bat weighs in at $1.10. If the bat is $1.10, the bat weighs in at $1.00. If the bat is $1.00, the bat weighs in at $1.00.
# B: What is the price of a bat when it's not worth the ball?
# A: The price of
#
# 🔹 Chain-of-Thought Answer:
# Q: If a bat and a ball cost $1.10 total, and the bat costs $1.00 more than the ball, how much does the ball cost?
# Let's think step by step. If you have two balls, you would spend $2.00 on them, and if you have only one, you would spend $1.00 on the ball. So that's $2.00.
# If you have two balls, it will cost you $2.00, and if you have only one, it will cost you $1.00.
# If you have two balls, it will cost you $2.00, and if you have only one, it will cost you $1.00.
# If you have two balls, it will cost you $2.00, and if you have only one, it will cost you $1.00.
# If you have two balls, it will cost you $2.00, and if you have only one, it will cost you $1.00.
# If you have two balls, it will cost you $2.00, and if you have only one, it will cost you $1.00.
# If you have two balls, it will cost you $2.00, and if you have only one, it will cost you $1.00.
# If you have two balls, it will cost you $2.00, and if you have only one
