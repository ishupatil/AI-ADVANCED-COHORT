# %% [markdown]
# <a href="https://colab.research.google.com/github/ishupatil/AI-ADVANCED-COHORT/blob/main/Prompt_enginering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
from transformers import pipeline
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.56.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.35.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.8.3)

# %%
# Load a local model (e.g., sentiment-analysis)
sentiment_model = pipeline("sentiment-analysis")
text_generation_model = pipeline("text-generation", model="gpt2")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Device set to use cpu
# Device set to use cpu

# %%
# 🔍 Task 1: Summarization Prompting

paragraph = """The quick brown fox jumps over the lazy dog to reach the other side of the hill."""

# Zero-shot prompt
zero_shot_prompt = f"Summarize the following paragraph:\n{paragraph}"
print("🔹 Zero-shot Summary:")
print(text_generation_model(zero_shot_prompt, max_length=50)[0]['generated_text'])

# Few-shot prompt
few_shot_prompt = """Example: 'She went to the store, bought groceries, and came back home in the afternoon.'
Summary: She bought groceries and returned home.

Now summarize the following paragraph:
""" + paragraph
print("\n🔹 Few-shot Summary:")
print(text_generation_model(few_shot_prompt, max_length=50)[0]['generated_text'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 🔹 Zero-shot Summary:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Summarize the following paragraph:
# The quick brown fox jumps over the lazy dog to reach the other side of the hill. The lazy dog follows, then the lazy fox comes back. The lazy dog reaches the other side of the hill, when it notices that the lazy dog's hand is being grabbed by the dog's leash, it bends over the lazy dog and pulls its head back on the leash, and then it pulls the leash back up again.
#
# The dog is not trained to follow a loose leash. The dog is trained to follow a loose leash.
#
# A dog is not trained to follow a loose leash. The dog is trained to follow a loose leash.
#
# A dog is not trained to follow a loose leash. The dog is trained to follow a loose leash.
#
# A dog is not trained to follow a loose leash. The dog is trained to follow a loose leash.
#
# A dog is not trained to follow a loose leash. The dog is trained to follow a loose leash.
#
# A dog is not trained to follow a loose leash. The dog is trained to follow a loose leash.
#
# The dog is not trained to follow a loose leash. The dog is trained to follow a loose leash.
#
# The dog is not trained to follow a loose leash. The dog is trained to follow a loose leash.
#
# The dog is not
#
# 🔹 Few-shot Summary:
# Example: 'She went to the store, bought groceries, and came back home in the afternoon.'
# Summary: She bought groceries and returned home.
#
# Now summarize the following paragraph:
# The quick brown fox jumps over the lazy dog to reach the other side of the hill. the store.
#
# (5) A short time later, the fox jumps over the lazy dog and returns home.
#
# Summary: The fox climbs over the lazy dog and returns home.
#
# Now summarize the following paragraph:
#
# The fox jumps over the lazy dog and returns home.
#
# (6) The dog jumps over the lazy dog and returns home in the morning.
#
# Summary:
#
# The dog jumps over the lazy dog and returns home in the morning.
#
# Now summarize the following paragraph:
#
# The dog jumps over the lazy dog and returns home in the morning.
#
# (7) The dog jumps over the lazy dog and returns home in the afternoon.
#
# Summary:
#
# The dog jumps over the lazy dog and returns home in the afternoon.
#
# Now summarize the following paragraph:
#
# The dog jumps over the lazy dog and returns home in the afternoon.
#
# (8) The dog jumps over the lazy dog and returns home in the evening.
#
# Summary:
#
# The dog jumps over the lazy dog and returns home in the evening.
#
# Now summarize the following paragraph:
#
# The dog jumps over the lazy dog and returns home in the morning.
#
# (9) The dog

# %%
# 🧪 Task 2: Sentiment Classification

review_text = "The new update is fantastic – it made the app so much smoother and I absolutely love it!"

# Basic prompt
print("\n🔹 Basic Sentiment Classification:")
print(sentiment_model(review_text))

# Role-based prompt (simulated)
role_based_prompt = f"You are a sentiment analysis expert. Classify the sentiment of this review: '{review_text}'"
print("\n🔹 Role-based Sentiment Classification (simulated):")
print(text_generation_model(role_based_prompt, max_length=50)[0]['generated_text'])
# Out:
# 🔹 Basic Sentiment Classification:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'label': 'POSITIVE', 'score': 0.9998791217803955}]
#
# 🔹 Role-based Sentiment Classification (simulated):
# You are a sentiment analysis expert. Classify the sentiment of this review: 'The new update is fantastic – it made the app so much smoother and I absolutely love it!' –
#
# 'The update made the app so much smoother and I absolutely love it!' – 'My first app was too small for me. The app felt too big for me. My second app was so bloated that I couldn't even use it and still have to use it. So the third app was not up to the task at all' –
#
# 'The app felt too big for me. The app felt too big for me. My second app was so bloated that I couldn't even use it and still have to use it. So the third app was not up to the task at all' – 'The app felt too big for me. The app felt too big for me. My second app was so bloated that I couldn't even use it and still have to use it. So the third app was not up to the task at all' – 'The app felt too big for me. The app felt too big for me. My second app was so bloated that I couldn't even use it and still have to use it. So the third app was not up to the task at all' – 'The app felt too big for me. The app felt too big for me. My second app was so bloated that I couldn't even use it

# %%
# 🧠 Task 3: Q&A with Chain-of-Thought

question = "If a bat and a ball cost $1.10 total, and the bat costs $1.00 more than the ball, how much does the ball cost?"

# Direct prompt
direct_prompt = f"Q: {question}\nA:"
print("\n🔹 Direct Answer:")
print(text_generation_model(direct_prompt, max_length=50)[0]['generated_text'])

# Chain-of-thought prompt
cot_prompt = f"Q: {question}\nLet's think step by step."
print("\n🔹 Chain-of-Thought Answer:")
print(text_generation_model(cot_prompt, max_length=150)[0]['generated_text'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 🔹 Direct Answer:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=150) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Q: If a bat and a ball cost $1.10 total, and the bat costs $1.00 more than the ball, how much does the ball cost?
# A: A bat and a ball cost $1.10 as opposed to $10.00 for the ball.
# (Source: "The Bat and the Ball", B.J. Lacey, and William K. Hart, "The Bat and the Ball", Volume I, Number 1, The University of California Press, San Francisco, California, 1989, pp. 787-804; "The Bat and the Ball", Volume II, Number 1, The University of California Press, San Francisco, California, 1989, pp. 805-826.)
# Source: "The Bat and the Ball", The University of California Press, San Francisco, California, 1989, pp. 787-804; "The Bat and the Ball", Volume II, Number 1, The University of California Press, San Francisco, California, 1989, pp. 805-826.)
# Source: "The Bat and the Ball", The University of California Press, San Francisco, California, 1989, pp. 805-826.)
# Source: "The Bat and the Ball", Volume II, Number 1, The University of California Press, San Francisco, California, 1989, pp. 805-826.)
# Source: "The Bat and the Ball",
#
# 🔹 Chain-of-Thought Answer:
# Q: If a bat and a ball cost $1.10 total, and the bat costs $1.00 more than the ball, how much does the ball cost?
# Let's think step by step. If you're wondering about the ball, I'll give you an estimate. You'll want to think about the size, weight, and shape of the ball (the ball is about 2 inches and 3 cm wide). The size of the ball is 3 inches long by 3 cm wide and 1.5 inches in diameter. The weight is 2.5 pounds.
# The weight and shape of the ball is 1.25 pounds (3.3 kg). The diameter of the ball is 2.5 cm and 3.0 cm. The diameter of the ball is 1.75 cm and 3.0 cm.
# Let's start with 3.0 cm (3.5 inches). It's a lot, but it's not too big. The diameter of your ball isn't 1.25 cm (4 cm). It's a lot bigger.
# The weight of the ball is 1.75 pounds (4.3 kg). The diameter of the ball is 2.5 cm and 3.0 cm.
# If you're wondering about the ball size, you might need to look at the dimensions. The diameter of the ball is 1.25 cm (4.3 kg). The diameter of the ball is 2.5 cm and 3.0 cm. The
